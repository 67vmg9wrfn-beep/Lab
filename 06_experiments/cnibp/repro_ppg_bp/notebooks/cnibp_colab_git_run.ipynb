# %% [markdown]
# # CNIBP Reproduction (Git, Robust)\n目标：Run all 自动执行并记录日志。

# %%
# 改成你的仓库地址\nGIT_REPO = 'https://github.com/<your_org>/<your_repo>.git'\nGIT_BRANCH = 'main'\nPROJECT_SUBDIR = '06_experiments/cnibp/repro_ppg_bp'

# %%
from google.colab import drive\ndrive.mount('/content/drive')

# %%
# %%bash\nset -euo pipefail\ncd /content\nrm -rf repo_src\ngit clone --depth 1 --branch "$GIT_BRANCH" "$GIT_REPO" repo_src

# %%
import os\nPROJECT_ROOT = f'/content/repo_src/{PROJECT_SUBDIR}'\nprint('PROJECT_ROOT=', PROJECT_ROOT)\nassert os.path.exists(PROJECT_ROOT)

# %%
# %%bash\nset -euo pipefail\nDATA_ROOT=/content/drive/MyDrive/bp_kachuee_cach\nfor p in Part_0.mat Part_1.mat Part_2.mat Part_3.mat Part_4.mat; do\n  test -f "$DATA_ROOT/$p" || { echo "Missing file: $DATA_ROOT/$p"; exit 2; }\ndone\necho "All MAT files found."

# %%
# %%bash\nset -euo pipefail\npython -m pip install -r "$PROJECT_ROOT/requirements_colab.txt"

# %%
# %%bash\nset -euo pipefail\nOUT_ROOT=/content/drive/MyDrive/cnibp_repro_outputs\nmkdir -p "$OUT_ROOT"\nLOG_FILE="$OUT_ROOT/last_run.log"\nPYTHONPATH="$PROJECT_ROOT/src:${PYTHONPATH:-}" python -m cnibp_repro.run_repro \\n  --drive_root /content/drive/MyDrive/bp_kachuee_cach \\n  --config "$PROJECT_ROOT/configs/paper_repro.json" \\n  --output_root "$OUT_ROOT" 2>&1 | tee "$LOG_FILE"
