# %% [markdown]
# # CNIBP Reproduction (Colab)\n按论文流程复现：预处理 -> 质量检查 -> 5折训练评估。

# %%
from google.colab import drive\ndrive.mount('/content/drive')

# %%
# %cd /content/Lab/06_experiments/cnibp/repro_ppg_bp\n!python -m pip install -r requirements_colab.txt

# %%
import os\nos.environ['PYTHONPATH'] = '/content/Lab/06_experiments/cnibp/repro_ppg_bp/src:' + os.environ.get('PYTHONPATH','')

# %%
# !python -m cnibp_repro.run_repro \\n  --drive_root /content/drive/MyDrive/bp_kachuee_cach \\n  --config /content/Lab/06_experiments/cnibp/repro_ppg_bp/configs/paper_repro.json \\n  --output_root /content/drive/MyDrive/cnibp_repro_outputs
